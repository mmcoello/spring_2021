# %%
import scipy as S
import scipy.io
import numpy as np
import xarray as xr
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pylab as pl
import matplotlib.dates as mdates
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib.ticker as mticker
from matplotlib.lines import Line2D

# %%
# set input directory of metgrid data
datadir = '/home/sbarc/students/wrf4211/WPS_merissa/ERA5_metgrid/'

# set filename of metgrid data file you want to check
filename = 'met_em.d03.2017-05-24_18:00:00.nc'

# set filepath
filepath = datadir + filename

# open netcdf file
dat = xr.open_dataset(filepath)
print('Opened File:', filepath)
# Out:
# Opened File: /home/sbarc/students/wrf4211/WPS_merissa/ERA5_metgrid/met_em.d03.2017-05-24_18:00:00.nc

# %%
level_topo = np.arange(-50, 3500, 50)
dat['HGT_M'].plot(levels = level_topo)
plt.show()

# %%
dat['GHT'].sel(num_metgrid_levels = 11).plot()
plt.show()

# %%
# convert pressure to hpa
dat['PRES_hpa'] = dat['PRES']/100

# %%
dat['PRES_hpa'].sel(num_metgrid_levels = 11).plot()
plt.show()

# %%
dat['PRES_hpa'].sel(south_north = 50, west_east = 50).plot(y = 'num_metgrid_levels')
plt.show()
